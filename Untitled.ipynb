# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Sample - Superstore.xlsx')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  ...  Region  \
# 0   Consumer  United States        Henderson    Kentucky  ...   South
# 1   Consumer  United States        Henderson    Kentucky  ...   South
# 2  Corporate  United States      Los Angeles  California  ...    West
# 3   Consumer  United States  Fort Lauderdale     Florida  ...   South
# 4   Consumer  United States  Fort Lauderdale     Florida  ...   South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df1 = df.groupby('City', as_index=False)
df1['Profit'].agg(sum).sort_values('Profit', ascending=False).set_index(np.arange(1, len(df1) + 1)).head(10)
# Out:
#              City      Profit
# 1   New York City  62036.9837
# 2     Los Angeles  30440.7579
# 3         Seattle  29156.0967
# 4   San Francisco  17507.3854
# 5         Detroit  13181.7908
# 6       Lafayette  10018.3876
# 7         Jackson   7581.6828
# 8         Atlanta   6993.6629
# 9     Minneapolis   6824.5846
# 10      San Diego   6377.1960

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  ...  Region  \
# 0   Consumer  United States        Henderson    Kentucky  ...   South
# 1   Consumer  United States        Henderson    Kentucky  ...   South
# 2  Corporate  United States      Los Angeles  California  ...    West
# 3   Consumer  United States  Fort Lauderdale     Florida  ...   South
# 4   Consumer  United States  Fort Lauderdale     Florida  ...   South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#df2 from df that stores results of # of customers who got discount by each category and segment 
# number of customers = count
# category & segment = groupby

# %%
df_discount = df[df['Discount'] != 0]
df_discount.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8        9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10      11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Segment        Country             City       State  ...  Region  \
# 3   Consumer  United States  Fort Lauderdale     Florida  ...   South
# 4   Consumer  United States  Fort Lauderdale     Florida  ...   South
# 7   Consumer  United States      Los Angeles  California  ...    West
# 8   Consumer  United States      Los Angeles  California  ...    West
# 10  Consumer  United States      Los Angeles  California  ...    West
#
#          Product ID         Category Sub-Category  \
# ...

# %%
df_group = df_discount.groupby(['Category', 'Segment'])['Customer ID'].nunique()

# %%
df_group
# Out:
# Category         Segment
# Furniture        Consumer       304
#                  Corporate      185
#                  Home Office    104
# Office Supplies  Consumer       383
#                  Corporate      219
#                  Home Office    131
# Technology       Consumer       278
#                  Corporate      152
#                  Home Office     98
# Name: Customer ID, dtype: int64

# %%
df2 = pd.DataFrame(df_group)
df2
# Out:
#                              Customer ID
# Category        Segment
# Furniture       Consumer             304
#                 Corporate            185
#                 Home Office          104
# Office Supplies Consumer             383
#                 Corporate            219
#                 Home Office          131
# Technology      Consumer             278
#                 Corporate            152
#                 Home Office           98

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
# Create a dataframe called df3 from df that selects all columns and shows profit Ratio is greater than 30% and Ship Status is Early

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  ...  Region  \
# 0   Consumer  United States        Henderson    Kentucky  ...   South
# 1   Consumer  United States        Henderson    Kentucky  ...   South
# 2  Corporate  United States      Los Angeles  California  ...    West
# 3   Consumer  United States  Fort Lauderdale     Florida  ...   South
# 4   Consumer  United States  Fort Lauderdale     Florida  ...   South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df_copy['Profit_Ratio'] = df_copy['Profit'] / df_copy['Sales']
df_copy.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  ...  \
# 0   Consumer  United States        Henderson    Kentucky  ...
# 1   Consumer  United States        Henderson    Kentucky  ...
# 2  Corporate  United States      Los Angeles  California  ...
# 3   Consumer  United States  Fort Lauderdale     Florida  ...
# 4   Consumer  United States  Fort Lauderdale     Florida  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df3 = df_copy[(df_copy['Profit_Ratio'] > 0.3) & (df_copy['Ship Status'] == 'Shipped Early')]
df3.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 12      13  CA-2017-114412 2017-04-15 2017-04-20  Standard Class    AA-10480
# 13      14  CA-2016-161389 2016-12-05 2016-12-10  Standard Class    IM-15070
# 20      21  CA-2014-143336 2014-08-27 2014-09-01    Second Class    ZD-21925
# 25      26  CA-2016-121755 2016-01-16 2016-01-20    Second Class    EH-13945
# 50      51  CA-2015-115742 2015-04-18 2015-04-22  Standard Class    DP-13000
#
#      Segment        Country           City           State  ...  \
# 12  Consumer  United States        Concord  North Carolina  ...
# 13  Consumer  United States        Seattle      Washington  ...
# 20  Consumer  United States  San Francisco      California  ...
# 25  Consumer  United States    Los Angeles      California  ...
# 50  Consumer  United States     New Albany         Indiana  ...
#
#          Product ID         Category Sub-Category  \
# 12  OFF-PA-10002365  Office Supplies        Paper
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Which three states placed the most orders in year 2017? How many distinct orders did each state place?

# %%
import datetime

# %%
df4 = df.copy()

# %%
df4['year'] = pd.DatetimeIndex(df4['Order Date']).year

# %%
df4.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  ...  \
# 0   Consumer  United States        Henderson    Kentucky  ...
# 1   Consumer  United States        Henderson    Kentucky  ...
# 2  Corporate  United States      Los Angeles  California  ...
# 3   Consumer  United States  Fort Lauderdale     Florida  ...
# 4   Consumer  United States  Fort Lauderdale     Florida  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df4 = df4[df4['year'] == 2017]

# %%
df4.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 12      13  CA-2017-114412 2017-04-15 2017-04-20  Standard Class    AA-10480
# 23      24  US-2017-156909 2017-07-16 2017-07-18    Second Class    SF-20065
# 34      35  CA-2017-107727 2017-10-19 2017-10-23    Second Class    MA-17560
# 41      42  CA-2017-120999 2017-09-10 2017-09-15  Standard Class    LC-16930
# 43      44  CA-2017-139619 2017-09-19 2017-09-23  Standard Class    ES-14080
#
#         Segment        Country          City           State  ...  \
# 12     Consumer  United States       Concord  North Carolina  ...
# 23     Consumer  United States  Philadelphia    Pennsylvania  ...
# 34  Home Office  United States       Houston           Texas  ...
# 41    Corporate  United States    Naperville        Illinois  ...
# 43    Corporate  United States     Melbourne         Florida  ...
#
#          Product ID         Category Sub-Category  \
# 12  OFF-PA-10002365  Office Supplies        Paper
# ...

# %%
df4_orders = df4.groupby('State')['Order ID'].count().sort_values(ascending=False).head(3)

# %%
df4_orders
# Out:
# State
# California    663
# New York      352
# Texas         317
# Name: Order ID, dtype: int64

# %%
df4.groupby('State')['Order ID'].nunique().sort_values(ascending=False).head(3)
# Out:
# State
# California    344
# New York      174
# Texas         164
# Name: Order ID, dtype: int64

# %%
df4_orders_df.head()
# Out:
#             Order ID
# State
# California       663
# New York         352
# Texas            317

# %%
df4_distinct = df4_orders.groupby('State')['Order ID'].count().sort_values(ascending=False).nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-62bdebe230a4> in <module>
# ----> 1 df4_distinct = df4_orders.groupby('State')['Order ID'].count().sort_values(ascending=False).nunique()
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     228         else:
#     229             if key not in self.obj:
# --> 230                 raise KeyError(f"Column not found: {key}")
#     231             return self._gotitem(key, ndim=1)
#     232
#
# KeyError: 'Column not found: Order ID'

# %%
df4_distinct
# Out:
# 38

# %%
# Which customer ID place the most orders in the furniture category in 2017? How many orders did they place?

# %%
id_distinct = df4[df4['Category'] == 'Furniture']['Customer ID'].value_counts()

# %%
id_distinct
# Out:
# SV-20365    8
# AH-10075    6
# Dp-13240    6
# ML-17410    5
# MO-17800    5
#            ..
# TB-21190    1
# LB-16735    1
# BN-11515    1
# CL-12565    1
# HA-14905    1
# Name: Customer ID, Length: 403, dtype: int64

# %%
# How many orders were placed in Los Angeles in 2017? How many orders contain products that start with the letter “C”?

# %%
la_orders = df4[df4['City'] == 'Los Angeles']['Order ID'].count()

# %%
la_orders
# Out:
# 210

# %%
c_products = df4[df4['City'] == 'Los Angeles']['Product Name'].str.startswith('C').sum()

# %%
c_products
# Out:
# 10
