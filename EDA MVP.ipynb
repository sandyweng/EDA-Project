# %% [markdown]
# # Best Subway Stations to Raise #StopAsianHate Awareness

# %% [markdown]
# ![test.png](attachment:test.png)

# %% [markdown]
# I used Seaborn to plot a bar chart of the busiest subway stations in NYC. The figure depicts the traffic for the top ten stations. The results suggest that 34 ST-PENN STATION is the busiest station for the past 6 months. However, I will take a closer look to see what part of the day is the best for the teams to work.
